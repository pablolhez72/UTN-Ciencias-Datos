# %% [markdown]
# # Herramientas Avanzadas

# %% [markdown]
# ## 3.	Sweetviz

# %% [markdown]
# Adicional a los anteriores, autoviz y Pandas_Profiling, en **Sweetviz**
# * detecta problematicas en datos de learn y prueba
# * auda mas en la seleccion de algoritmos
#
# Solo hace informe HTML

# %% [markdown]
# TP2 Unidada 3 Grupo I Lhez (c-Sweetviz)

# %%
# Instalar Sweetviz
# !pip install sweetviz seaborn
# !pip install numpy==1.24.4

# %%
# Importar librerías
import sweetviz as sv
import seaborn as sns
import pandas as pd
import numpy as np
import warnings

# %%
# Ignorar todos los warnings
warnings.filterwarnings("ignore")

# %%
# Cargar el dataset Titanic
#df = sns.load_dataset("titanic")
df=pd.read_csv("https://raw.githubusercontent.com/pablolhez72/UTN-Ciencias-Datos/main/Student_Habits.csv", sep=',', low_memory=False)

# %%
# Crear el informe EDA (análisis completo de un solo dataset)
informe = sv.analyze(df)
# Out:
#                                              |          | [  0%]   00:00 -> (? left)

# %%
# Mostrar el informe en HTML
informe.show_html("informe_sweetviz.html")
# Out:
# Report informe_sweetviz.html was generated! NOTEBOOK/COLAB USERS: the web browser MAY not pop up, regardless, the report IS saved in your notebook/colab files.
