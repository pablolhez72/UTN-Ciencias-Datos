# %% [markdown]
# # Herramientas Avanzadas

# %% [markdown]
# ## 1.	AutoViz

# %% [markdown]
# **Autoviz**
# * hay que entregarle el banco limpio y ordenado
# * conviene normalizar variables
# * ayuda para visualizar y encontrar relaciones de variables

# %% [markdown]
# TP2 Unidada 3 Grupo I Lhez (a-autoviz)

# %%
# Instalar autoviz si aún no lo tenés
# !pip install autoviz seaborn

# %%
# Importar librerías necesarias
import seaborn as sns
import pandas as pd
import warnings
from autoviz.AutoViz_Class import AutoViz_Class

# %%
# Ignorar todos los warnings
warnings.filterwarnings("ignore")

# 1. Cargar dataset
#df=pd.read_csv("/content/Student_Habits.csv", sep=',', low_memory=False)
df=pd.read_csv("https://raw.githubusercontent.com/pablolhez72/UTN-Ciencias-Datos/main/Student_Habits.csv", sep=',', low_memory=False)

# Visualizar primeras filas
print(df.head())
# Out:
#   student_id  age  gender  study_hours_per_day  social_media_hours  \
# 0    S1000    23   Female          0.0                  1.2
# 1    S1001    20   Female          6.9                  2.8
# 2    S1002    21     Male          1.4                  3.1
# 3    S1003    23   Female          1.0                  3.9
# 4    S1004    19   Female          5.0                  4.4
#
#    netflix_hours part_time_job  attendance_percentage  sleep_hours  \
# 0       1.1            No               85.0               8.0
# 1       2.3            No               97.3               4.6
# 2       1.3            No               94.8               8.0
# 3       1.0            No               71.0               9.2
# 4       0.5            No               90.9               4.9
#
#   diet_quality  exercise_frequency parental_education_level internet_quality  \
# 0     Fair               6                     Master            Average
# ...

# %%
# Configurar AutoViz
from autoviz.AutoViz_Class import AutoViz_Class
AV = AutoViz_Class()
df_resultado = AV.AutoViz(
filename="",
sep=",",
depVar="exam_score",
dfte=df,
header=0,
verbose=1,
chart_format="bokeh" # Opcional: gráficos interactivos
)
depVar="exam_score",
dfte=df,8
header=0,
verbose=1,
chart_format="bokeh" # Opcional: gráficos interactivos
# Out:
# Shape of your Data Set loaded: (1000, 16)
# #######################################################################################
# ######################## C L A S S I F Y I N G  V A R I A B L E S  ####################
# #######################################################################################
# Classifying variables in data set...
#     Number of Numeric Columns =  5
#     Number of Integer-Categorical Columns =  3
#     Number of String-Categorical Columns =  4
#     Number of Factor-Categorical Columns =  0
#     Number of String-Boolean Columns =  2
#     Number of Numeric-Boolean Columns =  0
#     Number of Discrete String Columns =  0
#     Number of NLP String Columns =  0
#     Number of Date Time Columns =  0
#     Number of ID Columns =  1
#     Number of Columns to Delete =  0
#     15 Predictors classified...
#         1 variable(s) removed since they were ID or low-information variables
#         List of variables removed: ['student_id']
#
# ...
